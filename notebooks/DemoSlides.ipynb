# %%
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}
# importing matplotlib as usual
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png', 'svg')

# %%
plt.bar([1, 2, 3], [10, 20, 15], tick_label=[2014, 2015, 2016], align='center')
plt.ylim(0,30);

# %%
from urllib.request import urlopen
import simplejson
import seaborn as sns
from pandas.core.frame import DataFrame
commits = DataFrame(simplejson.loads(urlopen("https://api.github.com/repos/pydata/pandas/stats/punch_card").read()), 
          columns=["weekday","hour","commits"])

# %%
commits.head()
# Out:
#    weekday  hour  commits
# 0        0     0       47
# 1        0     1       18
# 2        0     2       21
# 3        0     3        7
# 4        0     4        7

# %%
sns.heatmap(commits.pivot("weekday","hour","commits"));

# %%
commits.loc[commits['hour'] == 23, ['weekday','commits','hour']]
# Out:
#      weekday  commits  hour
# 23         0       85    23
# 47         1       73    23
# 71         2       64    23
# 95         3       84    23
# 119        4       74    23
# 143        5       32    23
# 167        6       73    23

# %%
normal_rnd = np.random.randn(500)*10 + 5

# %%
plt.style.use('default')
plt.subplot(1,2,1)
plt.boxplot(normal_rnd)
plt.subplot(1,2,2)
plt.hist(normal_rnd, orientation='horizontal', normed=True);
plt.xticks(rotation=30)
# Out:
# (array([ 0.   ,  0.005,  0.01 ,  0.015,  0.02 ,  0.025,  0.03 ,  0.035,
#          0.04 ,  0.045]), <a list of 10 Text xticklabel objects>)
